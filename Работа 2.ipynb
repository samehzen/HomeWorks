# %% [markdown]
# <a href="https://colab.research.google.com/github/samehzen/HomeWorks/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2025-03-21 142905.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
from math import sin , pi
x=float(input())
y=0
if 0<x<=1:
  y=x**2-x
else:
  y= x**2-sin(pi*x**2)
print(y)
# Out:
# 5
# 25.0

# %% [markdown]
# 2

# %%
n= int(input("n: "))
n=256
a=n//100
b=(n//10)%10
c=n%10
S=a**3+b**3+c**3
y=n**2==S
print(y)
# Out:
# n: 153
# False

# %% [markdown]
# 3

# %%
from math import sqrt
a= int(input("a: "))
R= int(input("R: "))
z= int(input("z: "))
z = a/sqrt(3)
if z<=R
print 'yes'
# Out:
#   File "<ipython-input-61-229c1c5a362f>", line 5
#     if z<=R
#            ^
# SyntaxError: expected ':'

# %% [markdown]
# 4

# %%
 def вычислить_возраст(год_рождения, месяц_рождения, год_сейчас, месяц_сейчас):
    возраст = год_сейчас - год_рождения
    if месяц_сейчас < месяц_рождения:
        возраст -= 1
    return возраст
год_рождения = int(input("Введите год рождения: "))
месяц_рождения = int(input("Введите месяц рождения (1-12): "))
год_сейчас = int(input("Введите текущий год: "))
месяц_сейчас = int(input("Введите текущий месяц (1-12): "))
возраст = вычислить_возраст(год_рождения, месяц_рождения, год_сейчас, месяц_сейчас)
print(f"Полных лет: {возраст}")
# Out:
# Введите год рождения: 1999
# Введите месяц рождения (1-12): 6
# Введите текущий год: 2025
# Введите текущий месяц (1-12): 3
# Полных лет: 25

# %% [markdown]
# 5

# %%
def восточный_календарь(год, опорный_год=1984):
    животные = ["Крыса", "Корова", "Тигр", "Заяц", "Дракон", "Змея", "Лошадь", "Овца", "Обезьяна", "Петух", "Собака", "Свинья"]
    цвета = ["Зеленый", "Зеленый", "Красный", "Красный", "Желтый", "Желтый", "Белый", "Белый", "Черный", "Черный"]
    разница = год - опорный_год
    индекс_животного = разница % 12
    индекс_цвета = разница % 10
год = int(input("Введите год: "))
print("Название года:", восточный_календарь(год))
# Out:
# Введите год: 2000
# Название года: None
