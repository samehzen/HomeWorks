# %% [markdown]
# <a href="https://colab.research.google.com/github/samehzen/HomeWorks/blob/main/untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2025-03-28 150421.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
import math
z=True
for x in range (41):
  z=True
  if x**2+x+41<=1:
    print(False)
  else:
    z=x*x+x+41
    for i in range (2,int(math.sqrt(z))+1):
      if z%i==0:
        z=False
  if z:
    print(x, z)
# Out:
# 0 41
# 1 43
# 2 47
# 3 53
# 4 61
# 5 71
# 6 83
# 7 97
# 8 113
# 9 131
# 10 151
# 11 173
# 12 197
# 13 223
# 14 251
# 15 281
# 16 313
# 17 347
# 18 383
# 19 421
# 20 461
# 21 503
# 22 547
# 23 593
# 24 641
# 25 691
# 26 743
# 27 797
# 28 853
# 29 911
# 30 971
# 31 1033
# 32 1097
# 33 1163
# 34 1231
# 35 1301
# 36 1373
# 37 1447
# 38 1523
# 39 1601

# %% [markdown]
# 2

# %%
from math import pow
a=float(input())
n=int(input())
s=1/a
for i in range (2, n+1):
   s=s+ 1 / pow(a, (2*i-2))

print (s)
# Out:
# 4
# 3
# 0.31640625

# %% [markdown]
# 3

# %%
from math import factorial, pow
epsilon = 1e-3
s=0
n=1
z=(pow(3,n)*math.factorial(n))/math.factorial(2*n)
while z>epsilon:
  z=(pow(3,n)*math.factorial(n))/math.factorial(2*n)
  s=s+z
  n=n+1

print(s)
# Out:
# 2.5324722152847152

# %% [markdown]
# 4

# %%
n=int(input())
x=0
z=False
for i in range(n):
  x=int(input())
  if x>0:
    z=True

print(z)
# Out:
# 3
# -7
# -8
# 6
# False
